# %%
import sys, os, glob
import pandas as pd
import numpy as np

import matplotlib
matplotlib.use('TkAgg')
from matplotlib import pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

sys.path.append('../src/')
from training import train_spotwise, train_gridwise
from count_datasets import load_count_dataset, load_count_grid_dataset, read_annotated_starray
from count_datasets import CountDataset, CountGridDataset, pseudo_hex_to_oddr
from gridnet_models import GridNetHexOddr

# %%
# First, pre-compute and save the output of spot-wise prediction using PCs:

# Build dataset using all tissues
data_dir = os.path.expanduser('~/Documents/Splotch_projects/Maynard_DLPFC/data/')

train_tissues = ['151507', '151508', '151509', '151510', '151669', '151670', '151671', '151672', '151673', '151674']
val_tissues = ['151675', '151676']
all_tissues = train_tissues + val_tissues

pcafiles = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs_PCs.tsv') % s for s in all_tissues]
annotfiles = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in all_tissues]

spots_pca = load_count_grid_dataset(pcafiles, annotfiles)

# Load pretrained model operating on count PCs
spot_clf_pca = nn.Sequential(
    nn.Linear(2150, 500),
    nn.Linear(500, 100),
    nn.BatchNorm1d(100),
    nn.ReLU(),
    
    nn.Linear(100, 100),
    nn.Linear(100, 50),
    nn.BatchNorm1d(50),
    nn.ReLU(),
    
    nn.Linear(50, 7)
)
    
H_VISIUM = 78
W_VISIUM = 64
gnet_pca = GridNetHexOddr(spot_clf_pca, (NUM_PCS,), (H_VISIUM, W_VISIUM), n_classes=7, use_bn=False)

best_parameters = 'gnet_pca.pth'
if torch.cuda.is_available():
    gnet_pca.load_state_dict(torch.load(best_parameters))
else:
    gnet_pca.load_state_dict(torch.load(best_parameters, map_location=torch.device('cpu')))

gnet_pca.eval()
# Out:
# GridNetHexOddr(
#   (patch_classifier): Sequential(
#     (0): Linear(in_features=2150, out_features=500, bias=True)
#     (1): Linear(in_features=500, out_features=100, bias=True)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=100, bias=True)
#     (5): Linear(in_features=100, out_features=50, bias=True)
#     (6): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): Linear(in_features=50, out_features=7, bias=True)
#   )
#   (corrector): Sequential(
#     (0): Conv2d(7, 32, kernel_size=1, stride=1)
#     (1): Conv2d(32, 32, kernel_size=1, stride=1)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=1, stride=1)
#     (4): Conv2d(32, 32, kernel_size=1, stride=1)
#     (5): ReLU()
#     (6): Conv2d(32, 7, kernel_size=1, stride=1)
#   )
# )

# %%
# Compute logits from spot-wise prediction and save results
for i, tissue_id in enumerate(all_tissues):
    x, y = spots_pca[i]
    x = torch.unsqueeze(x, 0)
    
    with torch.no_grad():
        outputs = gnet_pca.patch_predictions(x)
    
    logits = outputs[0].data.numpy()
    np.save('maynard_pcapred_maps/maynard_%s_logits_oddr' % tissue_id, logits)

# %%
# Next, define a custom Dataset class that takes paired logit maps from spot-wise prediction on images, counts
# and concatenates them into a single model input.
class ConcatDataset(Dataset):
    def __init__(self, logits1, logits2, annot_files):
        super(ConcatDataset, self).__init__()
        
        if not len(logits1)==len(logits1) or not len(logits1)==len(annot_files):
            raise ValueError('Number of logit files and annot files must match.')
        
        self.logits1 = logits1
        self.logits2 = logits2
        self.annot_files = annot_files
    
    def __len__(self):
        return len(self.logits1)
    
    def __getitem__(self, idx):
        f1 = np.load(self.logits1[idx])
        f2 = np.load(self.logits2[idx])
        feat_grid = torch.tensor(np.concatenate((f1, f2), axis=0))
        
        annot_grid = torch.zeros(feat_grid.shape[1:])
        
        amat = pd.read_csv(self.annot_files[idx], header=0, index_col=0, sep='\t')
        for cstr in amat.columns:
            x_vis, y_vis = map(int, cstr.split('_'))
            x, y = pseudo_hex_to_oddr(x_vis, y_vis)
            
            if np.sum(amat[cstr].values) > 0:
                annot_grid[y,x] = np.argmax(amat[cstr].values) + 1
        
        return feat_grid.float(), annot_grid.long()
        
    
count_logits_train = ['maynard_pcapred_maps/maynard_%s_logits_oddr.npy' % t for t in train_tissues]
img_logits_train = ['maynard_imgpred_maps/maynard_%s_logits_oddr.npy' % t for t in train_tissues]
annots_train = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % t for t in train_tissues]

count_logits_val = ['maynard_pcapred_maps/maynard_%s_logits_oddr.npy' % t for t in val_tissues]
img_logits_val = ['maynard_imgpred_maps/maynard_%s_logits_oddr.npy' % t for t in val_tissues]
annots_val = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % t for t in val_tissues]

df = pd.read_csv(annots_train[0], header=0, index_col=0, sep='\t')
annot_names = list(df.index.values)
N_CLASSES = len(annot_names)

train_set = ConcatDataset(count_logits_train, img_logits_train, annots_train)
val_set = ConcatDataset(count_logits_val, img_logits_val, annots_val)

x, y = val_set[0]

pca_preds = x[:N_CLASSES, :, :].data.numpy().argmax(axis=0) + 1
pca_preds[y==0] = 0

img_preds = x[N_CLASSES:, :, :].data.numpy().argmax(axis=0) + 1
img_preds[y==0] = 0

fig, ax = plt.subplots(1,3)
ax[0].imshow(y.data.numpy(), vmin=0, vmax=N_CLASSES)
ax[1].imshow(pca_preds, vmin=0, vmax=N_CLASSES)
ax[2].imshow(img_preds, vmin=0, vmax=N_CLASSES)
plt.show()

# %%
# Finally, define a g-network operating on ConcatDataset and train
class GridNetHexConcat(GridNetHexOddr):
    def __init__(self, concat_dim, grid_shape, n_classes):
        self.concat_dim = concat_dim
        
        pc = nn.Linear(1,1)
        super(GridNetHexConcat, self).__init__(pc, (concat_dim,), grid_shape, n_classes, 
                                         use_bn=False, atonce_patch_limit=None)
            
    def _init_corrector(self):
        cnn_layers = []
        cnn_layers.append(nn.Conv2d(self.concat_dim, self.concat_dim, 3, padding=1))
        cnn_layers.append(nn.ReLU())
        
        cnn_layers.append(nn.Conv2d(self.concat_dim, self.concat_dim, 5, padding=2))
        cnn_layers.append(nn.ReLU())
        
        cnn_layers.append(nn.Conv2d(self.concat_dim, self.concat_dim, 5, padding=2))
        cnn_layers.append(nn.ReLU())
        
        cnn_layers.append(nn.Conv2d(self.concat_dim, self.n_classes, 3, padding=1))
        return nn.Sequential(*cnn_layers)
    
    def patch_predictions(self, x):
        return x

gnet_concat = GridNetHexConcat(2*N_CLASSES, (H_VISIUM, W_VISIUM), n_classes=N_CLASSES)
    
dataloader = {
    'train': DataLoader(train_set, batch_size=1, shuffle=True),
    'val': DataLoader(val_set, batch_size=1)
}

loss = nn.CrossEntropyLoss()

# Only optimize the parameters in the g-network
optimizer = torch.optim.Adam(gnet_concat.corrector.parameters(), lr=1e-3)

gnet_concat, val_hist, train_hist = train_gridwise(gnet_concat, dataloader, loss, optimizer, num_epochs=100,
                                    outfile='../modgnet_concat.pth')
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.5112 Acc: 0.3715
# val Loss: 1.3348 Acc: 0.5371
#
# Epoch 1/99
# ----------
# train Loss: 0.8330 Acc: 0.7151
# val Loss: 0.9673 Acc: 0.6484
#
# Epoch 2/99
# ----------
# train Loss: 0.5497 Acc: 0.7905
# val Loss: 0.8684 Acc: 0.6774
#
# Epoch 3/99
# ----------
# train Loss: 0.4424 Acc: 0.8242
# val Loss: 0.6659 Acc: 0.7508
#
# Epoch 4/99
# ----------
# train Loss: 0.3493 Acc: 0.8578
# val Loss: 0.5575 Acc: 0.7979
#
# Epoch 5/99
# ----------
# train Loss: 0.2838 Acc: 0.8833
# val Loss: 0.6005 Acc: 0.7963
#
# Epoch 6/99
# ----------
# train Loss: 0.2372 Acc: 0.9006
# val Loss: 0.5741 Acc: 0.8003
#
# Epoch 7/99
# ----------
# train Loss: 0.2290 Acc: 0.9011
# val Loss: 0.5709 Acc: 0.8105
#
# Epoch 8/99
# ----------
# train Loss: 0.2105 Acc: 0.9107
# val Loss: 0.5040 Acc: 0.8138
#
# Epoch 9/99
# ----------
# train Loss: 0.1972 Acc: 0.9173
# val Loss: 0.5870 Acc: 0.8219
#
# Epoch 10/99
# ----------
# train Loss: 0.2141 Acc: 0.9086
# val Loss: 0.4829 Acc: 0.8315
#
# Epoch 11/99
# ----------
# train Loss: 0.1867 Acc: 0.9195
# val Loss: 0.4962 Acc: 0.8149
#
# Epoch 12/99
# ----------
# train Loss: 0.1920 Acc: 0.9190
# val Loss: 0.6475 Acc: 0.7923
#
# Epoch 13/99
# ----------
# train Loss: 0.1577 Acc: 0.9314
# val Loss: 0.4974 Acc: 0.8244
#
# Epoch 14/99
# ----------
# train Loss: 0.1789 Acc: 0.9226
# val Loss: 0.5517 Acc: 0.8172
#
# Epoch 15/99
# ----------
# train Loss: 0.1630 Acc: 0.9285
# val Loss: 0.5292 Acc: 0.8316
#
# Epoch 16/99
# ----------
# train Loss: 0.1701 Acc: 0.9267
# val Loss: 0.4824 Acc: 0.8161
#
# Epoch 17/99
# ----------
# train Loss: 0.1628 Acc: 0.9301
# val Loss: 0.6173 Acc: 0.8043
#
# Epoch 18/99
# ----------
# train Loss: 0.1753 Acc: 0.9271
# val Loss: 0.4893 Acc: 0.8259
#
# Epoch 19/99
# ----------
# train Loss: 0.1662 Acc: 0.9288
# val Loss: 0.5740 Acc: 0.8194
#
# Epoch 20/99
# ----------
# train Loss: 0.1505 Acc: 0.9343
# val Loss: 0.4925 Acc: 0.8298
#
# Epoch 21/99
# ----------
# train Loss: 0.1522 Acc: 0.9339
# val Loss: 0.5462 Acc: 0.8234
#
# Epoch 22/99
# ----------
# train Loss: 0.1541 Acc: 0.9339
# val Loss: 0.5333 Acc: 0.8271
#
# Epoch 23/99
# ----------
# train Loss: 0.1538 Acc: 0.9343
# val Loss: 0.4792 Acc: 0.8224
#
# Epoch 24/99
# ----------
# train Loss: 0.1556 Acc: 0.9322
# val Loss: 0.5674 Acc: 0.8208
#
# Epoch 25/99
# ----------
# train Loss: 0.1439 Acc: 0.9382
# val Loss: 0.4909 Acc: 0.8224
#
# Epoch 26/99
# ----------
# train Loss: 0.1513 Acc: 0.9350
# val Loss: 0.4910 Acc: 0.8322
#
# Epoch 27/99
# ----------
# train Loss: 0.1414 Acc: 0.9392
# val Loss: 0.5065 Acc: 0.8234
#
# Epoch 28/99
# ----------
# train Loss: 0.1395 Acc: 0.9405
# val Loss: 0.5126 Acc: 0.8406
#
# Epoch 29/99
# ----------
# train Loss: 0.1477 Acc: 0.9359
# val Loss: 0.5495 Acc: 0.8318
#
# Epoch 30/99
# ----------
# train Loss: 0.1523 Acc: 0.9337
# val Loss: 0.5018 Acc: 0.8194
#
# Epoch 31/99
# ----------
# train Loss: 0.1475 Acc: 0.9346
# val Loss: 0.6257 Acc: 0.8148
#
# Epoch 32/99
# ----------
# train Loss: 0.1423 Acc: 0.9400
# val Loss: 0.4600 Acc: 0.8436
#
# Epoch 33/99
# ----------
# train Loss: 0.1293 Acc: 0.9445
# val Loss: 0.4973 Acc: 0.8329
#
# Epoch 34/99
# ----------
# train Loss: 0.1262 Acc: 0.9467
# val Loss: 0.5449 Acc: 0.8332
#
# Epoch 35/99
# ----------
# train Loss: 0.1331 Acc: 0.9423
# val Loss: 0.5627 Acc: 0.8271
#
# Epoch 36/99
# ----------
# train Loss: 0.1343 Acc: 0.9431
# val Loss: 0.5507 Acc: 0.8155
#
# Epoch 37/99
# ----------
# train Loss: 0.1339 Acc: 0.9412
# val Loss: 0.7058 Acc: 0.8149
#
# Epoch 38/99
# ----------
# train Loss: 0.1219 Acc: 0.9481
# val Loss: 0.5291 Acc: 0.8359
#
# Epoch 39/99
# ----------
# train Loss: 0.1200 Acc: 0.9470
# val Loss: 0.5958 Acc: 0.8316
#
# Epoch 40/99
# ----------
# train Loss: 0.1362 Acc: 0.9407
# val Loss: 0.5034 Acc: 0.8368
#
# Epoch 41/99
# ----------
# train Loss: 0.1190 Acc: 0.9477
# val Loss: 0.6481 Acc: 0.8133
#
# Epoch 42/99
# ----------
# train Loss: 0.1290 Acc: 0.9440
# val Loss: 0.6734 Acc: 0.8119
#
# Epoch 43/99
# ----------
# train Loss: 0.1365 Acc: 0.9411
# val Loss: 0.5278 Acc: 0.8196
#
# Epoch 44/99
# ----------
# train Loss: 0.1379 Acc: 0.9400
# val Loss: 0.6472 Acc: 0.8013
#
# Epoch 45/99
# ----------
# train Loss: 0.1199 Acc: 0.9483
# val Loss: 0.5096 Acc: 0.8395
#
# Epoch 46/99
# ----------
# train Loss: 0.1224 Acc: 0.9465
# val Loss: 0.5401 Acc: 0.8364
#
# Epoch 47/99
# ----------
# train Loss: 0.1178 Acc: 0.9489
# val Loss: 0.5712 Acc: 0.8234
#
# Epoch 48/99
# ----------
# train Loss: 0.1128 Acc: 0.9518
# val Loss: 0.6505 Acc: 0.8244
#
# Epoch 49/99
# ----------
# train Loss: 0.1135 Acc: 0.9521
# val Loss: 0.5658 Acc: 0.8186
#
# Epoch 50/99
# ----------
# train Loss: 0.1150 Acc: 0.9502
# val Loss: 0.5233 Acc: 0.8356
#
# Epoch 51/99
# ----------
# train Loss: 0.1095 Acc: 0.9526
# val Loss: 0.7084 Acc: 0.8091
#
# Epoch 52/99
# ----------
# train Loss: 0.1182 Acc: 0.9508
# val Loss: 0.4969 Acc: 0.8331
#
# Epoch 53/99
# ----------
# train Loss: 0.1224 Acc: 0.9465
# val Loss: 0.6451 Acc: 0.8141
#
# Epoch 54/99
# ----------
# train Loss: 0.1240 Acc: 0.9452
# val Loss: 0.5549 Acc: 0.8389
#
# Epoch 55/99
# ----------
# train Loss: 0.1271 Acc: 0.9450
# val Loss: 0.5596 Acc: 0.8229
#
# Epoch 56/99
# ----------
# train Loss: 0.1164 Acc: 0.9501
# val Loss: 0.6424 Acc: 0.8238
#
# Epoch 57/99
# ----------
# train Loss: 0.1161 Acc: 0.9509
# val Loss: 0.5615 Acc: 0.8212
#
# Epoch 58/99
# ----------
# train Loss: 0.1226 Acc: 0.9472
# val Loss: 0.6227 Acc: 0.8245
#
# Epoch 59/99
# ----------
# train Loss: 0.1177 Acc: 0.9487
# val Loss: 0.5772 Acc: 0.8248
#
# Epoch 60/99
# ----------
# train Loss: 0.1038 Acc: 0.9547
# val Loss: 0.6288 Acc: 0.8148
#
# Epoch 61/99
# ----------
# train Loss: 0.1007 Acc: 0.9563
# val Loss: 0.6481 Acc: 0.8245
#
# Epoch 62/99
# ----------
# train Loss: 0.1003 Acc: 0.9568
# val Loss: 0.5947 Acc: 0.8199
#
# Epoch 63/99
# ----------
# train Loss: 0.1024 Acc: 0.9544
# val Loss: 0.6138 Acc: 0.8325
#
# Epoch 64/99
# ----------
# train Loss: 0.0996 Acc: 0.9558
# val Loss: 0.5799 Acc: 0.8222
#
# Epoch 65/99
# ----------
# train Loss: 0.1000 Acc: 0.9565
# val Loss: 0.7780 Acc: 0.8101
#
# Epoch 66/99
# ----------
# train Loss: 0.1073 Acc: 0.9532
# val Loss: 0.6025 Acc: 0.8225
#
# Epoch 67/99
# ----------
# train Loss: 0.1031 Acc: 0.9552
# val Loss: 0.6020 Acc: 0.8169
#
# Epoch 68/99
# ----------
# train Loss: 0.0935 Acc: 0.9597
# val Loss: 0.6323 Acc: 0.8234
#
# Epoch 69/99
# ----------
# train Loss: 0.0914 Acc: 0.9603
# val Loss: 0.6023 Acc: 0.8202
#
# Epoch 70/99
# ----------
# train Loss: 0.1056 Acc: 0.9545
# val Loss: 0.6778 Acc: 0.8254
#
# Epoch 71/99
# ----------
# train Loss: 0.0933 Acc: 0.9597
# val Loss: 0.6737 Acc: 0.8208
#
# Epoch 72/99
# ----------
# train Loss: 0.0931 Acc: 0.9590
# val Loss: 0.6343 Acc: 0.8252
#
# Epoch 73/99
# ----------
# train Loss: 0.0898 Acc: 0.9606
# val Loss: 0.7050 Acc: 0.8138
#
# Epoch 74/99
# ----------
# train Loss: 0.0945 Acc: 0.9596
# val Loss: 0.7040 Acc: 0.8118
#
# Epoch 75/99
# ----------
# train Loss: 0.0917 Acc: 0.9602
# val Loss: 0.6948 Acc: 0.8219
#
# Epoch 76/99
# ----------
# train Loss: 0.0878 Acc: 0.9613
# val Loss: 0.6333 Acc: 0.8212
#
# Epoch 77/99
# ----------
# train Loss: 0.0893 Acc: 0.9616
# val Loss: 0.6952 Acc: 0.8159
#
# Epoch 78/99
# ----------
# train Loss: 0.0884 Acc: 0.9615
# val Loss: 0.6301 Acc: 0.8241
#
# Epoch 79/99
# ----------
# train Loss: 0.0899 Acc: 0.9620
# val Loss: 0.7351 Acc: 0.8136
#
# Epoch 80/99
# ----------
# train Loss: 0.0863 Acc: 0.9613
# val Loss: 0.6760 Acc: 0.8271
#
# Epoch 81/99
# ----------
# train Loss: 0.0887 Acc: 0.9618
# val Loss: 0.7461 Acc: 0.8179
#
# Epoch 82/99
# ----------
# train Loss: 0.0863 Acc: 0.9622
# val Loss: 0.5900 Acc: 0.8344
#
# Epoch 83/99
# ----------
# train Loss: 0.0854 Acc: 0.9624
# val Loss: 0.6493 Acc: 0.8276
#
# Epoch 84/99
# ----------
# train Loss: 0.0852 Acc: 0.9625
# val Loss: 0.7400 Acc: 0.8198
#
# Epoch 85/99
# ----------
# train Loss: 0.0852 Acc: 0.9630
# val Loss: 0.6379 Acc: 0.8239
#
# Epoch 86/99
# ----------
# train Loss: 0.0909 Acc: 0.9594
# val Loss: 0.7149 Acc: 0.8209
#
# Epoch 87/99
# ----------
# train Loss: 0.0866 Acc: 0.9621
# val Loss: 0.6656 Acc: 0.8249
#
# Epoch 88/99
# ----------
# train Loss: 0.0886 Acc: 0.9606
# val Loss: 0.6492 Acc: 0.8254
#
# Epoch 89/99
# ----------
# train Loss: 0.0800 Acc: 0.9649
# val Loss: 0.7164 Acc: 0.8228
#
# Epoch 90/99
# ----------
# train Loss: 0.0811 Acc: 0.9649
# val Loss: 0.6349 Acc: 0.8235
#
# Epoch 91/99
# ----------
# train Loss: 0.0871 Acc: 0.9621
# val Loss: 0.8458 Acc: 0.8083
#
# Epoch 92/99
# ----------
# train Loss: 0.0840 Acc: 0.9630
# val Loss: 0.7113 Acc: 0.8194
#
# Epoch 93/99
# ----------
# train Loss: 0.0847 Acc: 0.9630
# val Loss: 0.7296 Acc: 0.8171
#
# Epoch 94/99
# ----------
# train Loss: 0.0816 Acc: 0.9642
# val Loss: 0.6082 Acc: 0.8326
#
# Epoch 95/99
# ----------
# train Loss: 0.0833 Acc: 0.9631
# val Loss: 0.6927 Acc: 0.8248
#
# Epoch 96/99
# ----------
# train Loss: 0.0815 Acc: 0.9647
# val Loss: 0.6910 Acc: 0.8218
#
# Epoch 97/99
# ----------
# train Loss: 0.0812 Acc: 0.9651
# val Loss: 0.6778 Acc: 0.8279
# Epoch 98/99
# ----------
# train Loss: 0.0769 Acc: 0.9666
# val Loss: 0.7081 Acc: 0.8255
#
# Epoch 99/99
# ----------
# train Loss: 0.0760 Acc: 0.9667
# val Loss: 0.7569 Acc: 0.8231
#
# Training complete in 8m 6s
# Best val Acc: 0.843647

# %%
fig = plt.figure()
plt.plot(train_hist, label='train')
plt.plot(val_hist, label='val')
plt.legend()

# %%
# Compare performance of g_concat to g_pca

sys.path.append(os.path.expanduser('~/Documents/Python/st_gridnet/'))
from src.utils import all_fgd_predictions
from plotting import performance_curves

true, pred_concat, smax_concat = all_fgd_predictions(dataloader['val'], gnet_concat, f_only=False)

pcafiles_val = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs_PCs.tsv') % s for s in val_tissues]
pcadata_val = load_count_grid_dataset(pcafiles_val, annots_val)
_, pred_pca, smax_pca = all_fgd_predictions(DataLoader(pcadata_val, batch_size=1), gnet_pca, f_only=False)

fig, ax, macro_auroc, macro_auprc = performance_curves(true, [smax_pca, smax_concat], annot_names, ['g_pca','g_concat'])
fig.suptitle('Concatenated Data')
plt.show()

acc_pca = np.sum(pred_pca == true) / len(true)
acc_concat = np.sum(pred_concat == true) / len(true)

print('g_pca    - ACC: %.3f, MACRO_AUROC: %.3f, MACRO_AUPRC: %.3f' % (acc_pca, macro_auroc[0], macro_auroc[0]))
print('g_concat - ACC: %.3f, MACRO_AUROC: %.3f, MACRO_AUPRC: %.3f' % (acc_concat, macro_auroc[1], macro_auprc[1]))
# Out:
# g_pca    - ACC: 0.830, MACRO_AUROC: 0.975, MACRO_AUPRC: 0.975
# g_concat - ACC: 0.844, MACRO_AUROC: 0.984, MACRO_AUPRC: 0.889
