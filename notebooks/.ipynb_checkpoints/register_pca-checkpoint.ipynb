# %%
import sys, os, glob
import pickle
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

import matplotlib
matplotlib.use('TkAgg')
from matplotlib import pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.utils.data import DataLoader

sys.path.append('../src/')
from training import train_spotwise, train_gridwise
from count_datasets import load_count_dataset, load_count_grid_dataset, read_annotated_starray
from count_datasets import CountDataset, CountGridDataset
from gridnet_models import GridNetHexOddr
from plotting import performance_curves

# %%
# Extract principal components from normalized count data.
data_dir = os.path.expanduser('~/Documents/Splotch_projects/Maynard_DLPFC/data/')

X = []
for cfile in glob.glob(os.path.join(data_dir, 'Countfiles_Visium_norm', '*.unified.tsv')):
    count_dat = pd.read_csv(cfile, sep='\t', header=0, index_col=0)
    X.append(count_dat.values.T)

X = np.vstack(X)
print(X.shape)

#pca = PCA()
#pca.fit(X)

pca = pickle.load(open('../models/trained_pca.pkl', 'rb'))

# %%
fig = plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('# PCs')
plt.ylabel('Fraction of variance explained')
plt.show()

# %%
np.sum(pca.explained_variance_ratio_[:2150])
# Out:
# 0.5047220707398039

# %%
# Construct training and validation sets from PCA-trained data
train_tissues = ['151507', '151508', '151509', '151510', '151669', '151670', '151671', '151672', '151673', '151674']
val_tissues = ['151675', '151676']

countfiles_train = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs.txt.unified.tsv') % s for s in train_tissues]
annotfiles_train = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in train_tissues]

countfiles_val = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs.txt.unified.tsv') % s for s in val_tissues]
annotfiles_val = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in val_tissues]

NUM_PCS = 2150

# Save PCs for each input array
for cf in countfiles_train + countfiles_val:
    count_dat = pd.read_csv(cf, header=0, index_col=0, sep='\t')
    X = pca.transform(count_dat.values.T)[:, :NUM_PCS]
    
    df = pd.DataFrame(X.T, columns=count_dat.columns, index=['PC%d' % i for i in range(NUM_PCS)])
    df.to_csv(cf.replace('.txt.unified.tsv', '_PCs.tsv'), sep='\t')
    
pcafiles_train = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs_PCs.tsv') % s for s in train_tissues]
pcafiles_val = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs_PCs.tsv') % s for s in val_tissues]

# Load full dataset into memory (though we most likely won't be able to do this on GPUs)
train_spot_pca = load_count_dataset(pcafiles_train, annotfiles_train)
val_spot_pca = load_count_dataset(pcafiles_val, annotfiles_val)

dataloader_spot_pca = {
    'train': DataLoader(train_spot_pca, batch_size=32, shuffle=True),
    'val': DataLoader(val_spot_pca, batch_size=32)
}

# %%
# Fit a basic fully-connected network to the top 2150 PCs (50% of variance)
df = pd.read_csv(annotfiles_train[0], header=0, index_col=0, sep='\t')
annot_names = list(df.index.values)

spot_clf_pca = nn.Sequential(
    nn.Linear(NUM_PCS, 500),
    nn.Linear(500, 100),
    nn.BatchNorm1d(100),
    nn.ReLU(),
    
    nn.Linear(100, 100),
    nn.Linear(100, 50),
    nn.BatchNorm1d(50),
    nn.ReLU(),
    
    nn.Linear(50, len(annot_names))
)

loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(spot_clf_pca.parameters(), lr=1e-4)

spot_clf_pca, val_hist, train_hist = train_spotwise(spot_clf_pca, dataloader_spot_pca, loss, optimizer, 40, 
                                                    display=False, outfile='../models/spot_classifier_pca.pth')

fig = plt.figure()
plt.plot(train_hist, label='train')
plt.plot(val_hist, label='val')
plt.legend()
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.9938 Acc: 0.6808
# val Loss: 0.7933 Acc: 0.7044
#
# Epoch 1/99
# ----------
# train Loss: 0.5899 Acc: 0.7916
# val Loss: 0.7352 Acc: 0.7175
#
# Epoch 2/99
# ----------
# train Loss: 0.4665 Acc: 0.8308
# val Loss: 0.7275 Acc: 0.7235
#
# Epoch 3/99
# ----------
# train Loss: 0.3545 Acc: 0.8782
# val Loss: 0.8460 Acc: 0.7054
#
# Epoch 4/99
# ----------
# train Loss: 0.2453 Acc: 0.9234
# val Loss: 0.9229 Acc: 0.6876
#
# Epoch 5/99
# ----------
# train Loss: 0.1640 Acc: 0.9537
# val Loss: 1.0544 Acc: 0.6801
#
# Epoch 6/99
# ----------
# train Loss: 0.1139 Acc: 0.9695
# val Loss: 1.0866 Acc: 0.6922
#
# Epoch 7/99
# ----------
# train Loss: 0.0911 Acc: 0.9752
# val Loss: 1.1805 Acc: 0.6813
#
# Epoch 8/99
# ----------
# train Loss: 0.0761 Acc: 0.9781
# val Loss: 1.2141 Acc: 0.6854
#
# Epoch 9/99
# ----------
# train Loss: 0.0676 Acc: 0.9803
# val Loss: 1.3174 Acc: 0.6731
#
# Epoch 10/99
# ----------
# train Loss: 0.0587 Acc: 0.9831
# val Loss: 1.3672 Acc: 0.6783
#
# Epoch 11/99
# ----------
# train Loss: 0.0534 Acc: 0.9838
# val Loss: 1.4726 Acc: 0.6707
#
# Epoch 12/99
# ----------
# train Loss: 0.0505 Acc: 0.9847
# val Loss: 1.4701 Acc: 0.6760
#
# Epoch 13/99
# ----------
# train Loss: 0.0459 Acc: 0.9863
# val Loss: 1.6211 Acc: 0.6717
#
# Epoch 14/99
# ----------
# train Loss: 0.0447 Acc: 0.9860
# val Loss: 1.5787 Acc: 0.6754
#
# Epoch 15/99
# ----------
# train Loss: 0.0450 Acc: 0.9854
# val Loss: 1.5503 Acc: 0.6746
#
# Epoch 16/99
# ----------
# train Loss: 0.0416 Acc: 0.9872
# val Loss: 1.5891 Acc: 0.6597
#
# Epoch 17/99
# ----------
# train Loss: 0.0389 Acc: 0.9876
# val Loss: 1.6530 Acc: 0.6699
#
# Epoch 18/99
# ----------
# train Loss: 0.0380 Acc: 0.9881
# val Loss: 1.7459 Acc: 0.6581
#
# Epoch 19/99
# ----------
# train Loss: 0.0348 Acc: 0.9884
# val Loss: 1.7524 Acc: 0.6696
#
# Epoch 20/99
# ----------
# train Loss: 0.0351 Acc: 0.9881
# val Loss: 1.8145 Acc: 0.6631
#
# Epoch 21/99
# ----------
# train Loss: 0.0350 Acc: 0.9884
# val Loss: 1.7072 Acc: 0.6686
#
# Epoch 22/99
# ----------
# train Loss: 0.0339 Acc: 0.9891
# val Loss: 1.8012 Acc: 0.6661
#
# Epoch 23/99
# ----------
# train Loss: 0.0318 Acc: 0.9899
# val Loss: 1.8266 Acc: 0.6693
#
# Epoch 24/99
# ----------
# train Loss: 0.0329 Acc: 0.9888
# val Loss: 1.8776 Acc: 0.6610
#
# Epoch 25/99
# ----------
# train Loss: 0.0290 Acc: 0.9901
# val Loss: 1.8396 Acc: 0.6647
#
# Epoch 26/99
# ----------
# train Loss: 0.0284 Acc: 0.9912
# val Loss: 1.8113 Acc: 0.6671
#
# Epoch 27/99
# ----------
# train Loss: 0.0283 Acc: 0.9907
# val Loss: 1.9569 Acc: 0.6639
#
# Epoch 28/99
# ----------
# train Loss: 0.0271 Acc: 0.9909
# val Loss: 1.8637 Acc: 0.6746
#
# Epoch 29/99
# ----------
# train Loss: 0.0273 Acc: 0.9914
# val Loss: 1.8796 Acc: 0.6673
#
# Epoch 30/99
# ----------
# train Loss: 0.0224 Acc: 0.9932
# val Loss: 1.9405 Acc: 0.6610
#
# Epoch 31/99
# ----------
# train Loss: 0.0267 Acc: 0.9913
# val Loss: 1.9818 Acc: 0.6646
#
# Epoch 32/99
# ----------
# train Loss: 0.0248 Acc: 0.9920
# val Loss: 1.9829 Acc: 0.6600
#
# Epoch 33/99
# ----------
# train Loss: 0.0237 Acc: 0.9923
# val Loss: 2.0193 Acc: 0.6616
#
# Epoch 34/99
# ----------
# train Loss: 0.0255 Acc: 0.9919
# val Loss: 1.8727 Acc: 0.6707
#
# Epoch 35/99
# ----------
# train Loss: 0.0246 Acc: 0.9917
# val Loss: 1.9505 Acc: 0.6687
#
# Epoch 36/99
# ----------
# train Loss: 0.0246 Acc: 0.9916
# val Loss: 2.0012 Acc: 0.6639
#
# Epoch 37/99
# ----------
# train Loss: 0.0206 Acc: 0.9935
# val Loss: 1.9750 Acc: 0.6663
#
# Epoch 38/99
# ----------
# train Loss: 0.0231 Acc: 0.9922
# val Loss: 1.9904 Acc: 0.6669
#
# Epoch 39/99
# ----------
# train Loss: 0.0213 Acc: 0.9930
# val Loss: 1.9570 Acc: 0.6726
#
# Epoch 40/99
# ----------
# train Loss: 0.0184 Acc: 0.9942
# val Loss: 2.0660 Acc: 0.6666
#
# Epoch 41/99
# ----------
# train Loss: 0.0182 Acc: 0.9944
# val Loss: 2.0245 Acc: 0.6644
#
# Epoch 42/99
# ----------
# train Loss: 0.0197 Acc: 0.9932
# val Loss: 2.1495 Acc: 0.6610
#
# Epoch 43/99
# ----------
# train Loss: 0.0223 Acc: 0.9923
# val Loss: 2.1386 Acc: 0.6671
#
# Epoch 44/99
# ----------
# train Loss: 0.0187 Acc: 0.9936
# val Loss: 2.0905 Acc: 0.6647
#
# Epoch 45/99
# ----------
# train Loss: 0.0183 Acc: 0.9938
# val Loss: 2.1075 Acc: 0.6657
#
# Epoch 46/99
# ----------
# train Loss: 0.0185 Acc: 0.9939
# val Loss: 2.0742 Acc: 0.6659
#
# Epoch 47/99
# ----------
# train Loss: 0.0165 Acc: 0.9945
# val Loss: 2.1457 Acc: 0.6686
#
# Epoch 48/99
# ----------
# train Loss: 0.0176 Acc: 0.9946
# val Loss: 2.1160 Acc: 0.6700
#
# Epoch 49/99
# ----------
# train Loss: 0.0185 Acc: 0.9937
# val Loss: 2.0945 Acc: 0.6704
#
# Epoch 50/99
# ----------
# train Loss: 0.0196 Acc: 0.9931
# val Loss: 2.0825 Acc: 0.6669
#
# Epoch 51/99
# ----------
# train Loss: 0.0167 Acc: 0.9946
# val Loss: 2.1974 Acc: 0.6611
#
# Epoch 52/99
# ----------
# train Loss: 0.0175 Acc: 0.9936
# val Loss: 2.1700 Acc: 0.6696
#
# Epoch 53/99
# ----------
# train Loss: 0.0164 Acc: 0.9943
# val Loss: 2.2394 Acc: 0.6710
#
# Epoch 54/99
# ----------
# train Loss: 0.0169 Acc: 0.9940
# val Loss: 2.0765 Acc: 0.6753
#
# Epoch 55/99
# ----------
# train Loss: 0.0174 Acc: 0.9943
# val Loss: 2.1821 Acc: 0.6699
#
# Epoch 56/99
# ----------
# train Loss: 0.0163 Acc: 0.9944
# val Loss: 2.1702 Acc: 0.6619
#
# Epoch 57/99
# ----------
# train Loss: 0.0159 Acc: 0.9952
# val Loss: 2.1799 Acc: 0.6674
#
# Epoch 58/99
# ----------
# train Loss: 0.0145 Acc: 0.9950
# val Loss: 2.2978 Acc: 0.6554
#
# Epoch 59/99
# ----------
# train Loss: 0.0173 Acc: 0.9947
# val Loss: 2.1723 Acc: 0.6679
#
# Epoch 60/99
# ----------
# train Loss: 0.0166 Acc: 0.9943
# val Loss: 2.2276 Acc: 0.6666
#
# Epoch 61/99
# ----------
# train Loss: 0.0156 Acc: 0.9948
# val Loss: 2.2792 Acc: 0.6650
#
# Epoch 62/99
# ----------
# train Loss: 0.0151 Acc: 0.9948
# val Loss: 2.3956 Acc: 0.6560
#
# Epoch 63/99
# ----------
# train Loss: 0.0162 Acc: 0.9948
# val Loss: 2.2045 Acc: 0.6676
#
# Epoch 64/99
# ----------
# train Loss: 0.0131 Acc: 0.9953
# val Loss: 2.1565 Acc: 0.6731
#
# Epoch 65/99
# ----------
# train Loss: 0.0134 Acc: 0.9955
# val Loss: 2.2658 Acc: 0.6690
#
# Epoch 66/99
# ----------
# train Loss: 0.0140 Acc: 0.9955
# val Loss: 2.2321 Acc: 0.6661
#
# Epoch 67/99
# ----------
# train Loss: 0.0121 Acc: 0.9959
# val Loss: 2.2692 Acc: 0.6709
#
# Epoch 68/99
# ----------
# train Loss: 0.0140 Acc: 0.9953
# val Loss: 2.3176 Acc: 0.6729
#
# Epoch 69/99
# ----------
# train Loss: 0.0145 Acc: 0.9953
# val Loss: 2.2112 Acc: 0.6697
#
# Epoch 70/99
# ----------
# train Loss: 0.0128 Acc: 0.9956
# val Loss: 2.3961 Acc: 0.6627
#
# Epoch 71/99
# ----------
# train Loss: 0.0140 Acc: 0.9953
# val Loss: 2.3018 Acc: 0.6616
#
# Epoch 72/99
# ----------
# train Loss: 0.0144 Acc: 0.9952
# val Loss: 2.3115 Acc: 0.6676
#
# Epoch 73/99
# ----------
# train Loss: 0.0133 Acc: 0.9953
# val Loss: 2.2330 Acc: 0.6700
#
# Epoch 74/99
# ----------
# train Loss: 0.0143 Acc: 0.9953
# val Loss: 2.3395 Acc: 0.6594
#
# Epoch 75/99
# ----------
# train Loss: 0.0131 Acc: 0.9957
# val Loss: 2.2672 Acc: 0.6676
#
# Epoch 76/99
# ----------
# train Loss: 0.0117 Acc: 0.9961
# val Loss: 2.2979 Acc: 0.6694
#
# Epoch 77/99
# ----------
# train Loss: 0.0116 Acc: 0.9961
# val Loss: 2.4262 Acc: 0.6661
#
# Epoch 78/99
# ----------
# train Loss: 0.0126 Acc: 0.9960
# val Loss: 2.3475 Acc: 0.6639
#
# Epoch 79/99
# ----------
# train Loss: 0.0120 Acc: 0.9965
# val Loss: 2.3968 Acc: 0.6693
#
# Epoch 80/99
# ----------
# train Loss: 0.0142 Acc: 0.9953
# val Loss: 2.3889 Acc: 0.6659
#
# Epoch 81/99
# ----------
# train Loss: 0.0116 Acc: 0.9960
# val Loss: 2.3080 Acc: 0.6743
#
# Epoch 82/99
# ----------
# train Loss: 0.0125 Acc: 0.9953
# val Loss: 2.4468 Acc: 0.6589
#
# Epoch 83/99
# ----------
# train Loss: 0.0120 Acc: 0.9963
# val Loss: 2.4053 Acc: 0.6623
#
# Epoch 84/99
# ----------
# train Loss: 0.0114 Acc: 0.9962
# val Loss: 2.3784 Acc: 0.6600
#
# Epoch 85/99
# ----------
# train Loss: 0.0109 Acc: 0.9961
# val Loss: 2.3785 Acc: 0.6676
#
# Epoch 86/99
# ----------
# train Loss: 0.0107 Acc: 0.9963
# val Loss: 2.3707 Acc: 0.6630
#
# Epoch 87/99
# ----------
# train Loss: 0.0119 Acc: 0.9958
# val Loss: 2.4727 Acc: 0.6629
#
# Epoch 88/99
# ----------
# train Loss: 0.0116 Acc: 0.9965
# val Loss: 2.3981 Acc: 0.6656
#
# Epoch 89/99
# ----------
# train Loss: 0.0115 Acc: 0.9965
# val Loss: 2.5370 Acc: 0.6583
#
# Epoch 90/99
# ----------
# train Loss: 0.0092 Acc: 0.9969
# val Loss: 2.2668 Acc: 0.6731
#
# Epoch 91/99
# ----------
# train Loss: 0.0109 Acc: 0.9966
# val Loss: 2.3763 Acc: 0.6659
#
# Epoch 92/99
# ----------
# train Loss: 0.0111 Acc: 0.9962
# val Loss: 2.4806 Acc: 0.6631
#
# Epoch 93/99
# ----------
# train Loss: 0.0108 Acc: 0.9964
# val Loss: 2.4610 Acc: 0.6600
#
# Epoch 94/99
# ----------
# train Loss: 0.0094 Acc: 0.9970
# val Loss: 2.4701 Acc: 0.6630
#
# Epoch 95/99
# ----------
# train Loss: 0.0098 Acc: 0.9966
# val Loss: 2.4684 Acc: 0.6647
#
# Epoch 96/99
# ----------
# train Loss: 0.0100 Acc: 0.9968
# val Loss: 2.4284 Acc: 0.6626
#
# Epoch 97/99
# ----------
# train Loss: 0.0101 Acc: 0.9965
# val Loss: 2.4981 Acc: 0.6657
# Epoch 98/99
# ----------
# train Loss: 0.0103 Acc: 0.9969
# val Loss: 2.4466 Acc: 0.6677
#
# Epoch 99/99
# ----------
# train Loss: 0.0110 Acc: 0.9962
# val Loss: 2.4374 Acc: 0.6716
#
# Training complete in 13m 40s
# Best val Acc: 0.723453

# %%
# Try training a g network on top of the PC-based spot classifier
train_grid_pca = load_count_grid_dataset(pcafiles_train, annotfiles_train)
val_grid_pca = load_count_grid_dataset(pcafiles_val, annotfiles_val)

dataloader_grid_pca = {
    'train': DataLoader(train_grid_pca, batch_size=1, shuffle=True),
    'val': DataLoader(val_grid_pca, batch_size=1, shuffle=False)
}

# %%
H_VISIUM = 78
W_VISIUM = 64
gnet_pca = GridNetHexOddr(spot_clf_pca, (NUM_PCS,), (H_VISIUM, W_VISIUM), n_classes=len(annot_names),
                 use_bn=False)

# Fixing the parameters of the patch classifier allows slightly faster training, even when only
#   optimizing the parameters of the corrector. 
for param in gnet_pca.patch_classifier.parameters():
    param.requires_grad = False

loss = nn.CrossEntropyLoss()

# Only optimize the parameters in the g-network
optimizer = torch.optim.Adam(gnet_pca.corrector.parameters(), lr=1e-3)

gnet_pca, val_hist, train_hist = train_gridwise(gnet_pca, dataloader_grid_pca, loss, optimizer, num_epochs=100,
                                  outfile='../models/gnet_pca.pth')

fig = plt.figure()
plt.plot(train_hist, label='train')
plt.plot(val_hist, label='val')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-5bf49a476912> in <module>
# ----> 1 from gridnet_models import GridNetHexOddr
#       2
#       3 H_VISIUM = 78
#       4 W_VISIUM = 64
#       5 gnet_pca = GridNetHexOddr(spot_clf_pca, (NUM_PCS,), (H_VISIUM, W_VISIUM), n_classes=len(annot_names),
#
# ~/Documents/Python/gridnet_count/src/gridnet_models.py in <module>
#       2
#       3 # TODO: gridnet_patches migrated from st_gridnet; join modules together
# ----> 4 from gridnet_patches import GridNetHex
#       5
#       6 # Like GridNetHex, but:
#
# ~/Documents/Python/gridnet_count/src/gridnet_patches.py in <module>
#       6 import numpy as np
#       7
# ----> 8 from .utils import class_auroc
#       9
#      10 # import the checkpoint API
#
# ImportError: attempted relative import with no known parent package

# %%
# Examine ROC, precision-recall performance of f, g models trained on PCs of count data

# f_PCA
true_vals, patch_preds_pca, patch_smax_pca = all_fgd_predictions(dataloader_grid_pca['val'], gnet_pca, f_only=True)

# g_PCA
_, grid_preds_pca, grid_smax_pca = all_fgd_predictions(dataloader_grid_pca['val'], gnet_pca)

fig, ax, macro_auroc, macro_auprc = performance_curves(true_vals, [patch_smax_pca, grid_smax_pca], annot_names, ['f','g'])
fig.suptitle('Count Data - Top 2150 PCs')
plt.show()

acc = np.sum(patch_preds_pca == true_vals) / len(true_vals)

print('f predictions - count PCA')
print('ACC: %.3f, MACRO_AUROC: %.3f, MACRO_AUPRC: %.3f' % (acc, macro_auroc[0], macro_auprc[0]))

acc = np.sum(grid_preds_pca == true_vals) / len(true_vals)

print('g predictions - count PCA')
print('ACC: %.3f, MACRO_AUROC: %.3f, MACRO_AUPRC: %.3f' % (acc, macro_auroc[1], macro_auprc[1]))
# Out:
# f predictions - count PCA
# ACC: 0.716, MACRO_AUROC: 0.948, MACRO_AUPRC: 0.733
# g predictions - count PCA
# ACC: 0.830, MACRO_AUROC: 0.975, MACRO_AUPRC: 0.863

# %%
# Now see what happens if we try making a consensus predictor using image data as well:

# f_img:
patch_smax_img = np.load('../outputs/maynard_imgpred_maps/maynard_smax_f_6fold_5_oddr.npy')

# g_img:
grid_smax_img = np.load('../outputs/maynard_imgpred_maps/maynard_smax_g_6fold_5_oddr.npy')

# Create consensus prediction
consensus_smax = np.array((grid_smax_pca, grid_smax_img)).mean(axis=0)

fig, ax, macro_auroc, macro_auprc = performance_curves(true_vals, [grid_smax_pca, grid_smax_img, consensus_smax], 
                                                       annot_names, ['counts_PCA', 'image', 'consensus'])
fig.suptitle('Count_PCs + Image Data')
plt.show()

consensus_pred = np.argmax(consensus_smax, axis=1)
acc = np.sum(consensus_pred == true_vals) / len(true_vals)

print('g predictions (consensus) - count_pca + image data')
print('ACC: %.3f, MACRO_AUROC: %.3f, MACRO_AUPRC: %.3f' % (acc, macro_auroc[2], macro_auprc[2]))
# Out:
# g predictions (consensus) - count_pca + image data
# ACC: 0.748, MACRO_AUROC: 0.973, MACRO_AUPRC: 0.842
