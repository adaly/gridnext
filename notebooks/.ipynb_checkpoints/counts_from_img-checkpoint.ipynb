# %%
import os
import sys
import copy, time
import progressbar
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import models, transforms

sys.path.append('../src/')
from multimodal_datasets import MultiModalDataset, MultiModalGridDataset

# %%
# Create multi-modal datasets

data_dir = '/Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/'

train_tissues = ['151507', '151508', '151509', '151510', '151669', '151670', '151671', '151672', '151673', '151674']
val_tissues = ['151675', '151676']

countfiles_train = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs.txt.unified.tsv') % s for s in train_tissues]
annotfiles_train = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in train_tissues]
imgfiles_train = [os.path.join(data_dir, 'maynard_patchdata_oddr/%s_full_image/') % s for s in train_tissues]

countfiles_val = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs.txt.unified.tsv') % s for s in val_tissues]
annotfiles_val = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in val_tissues]
imgfiles_val = [os.path.join(data_dir, 'maynard_patchdata_oddr/%s_full_image/') % s for s in val_tissues]

# Joana's manually curated list of layer marker genes:
jp_markers = {
    'MBP': 'ENSG00000197971',    # WM
    'SNAP25': 'ENSG00000132639', # GM (Layers 1-6)
    'PCP4': 'ENSG00000183036',   # Layer 5
    'RORB': 'ENSG00000198963',   # Layer 4
    'SYNPR': 'ENSG00000163630',  # Layer 6
    'MFGE8': 'ENSG00000140545',
    'CBLN2': 'ENSG00000141668',
    'RPRM': 'ENSG00000177519',
    'NR4A2': 'ENSG00000153234',
    'CXCL14': 'ENSG00000145824',
    'C1QL2': 'ENSG00000144119',
    'CUX2': 'ENSG00000111249',
    'CARTPT': 'ENSG00000164326',
    'CCK': 'ENSG00000187094'
    }
# Note that CountDataset (extended by MultiModalDataset) orders selected genes based on row order in count file.
# This corresponds to alphanumberical ordering in our case, so we can sort by ENSEMBL ID to get same ordering.
select_genes = sorted([ensmbl for _, ensmbl in jp_markers.items()])

# Preprocessing transform for image data
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

mmp_train = MultiModalDataset(countfiles_train, imgfiles_train, annotfiles_train, 
                              select_genes=select_genes, img_transforms=preprocess)
mmp_val = MultiModalDataset(countfiles_val, imgfiles_val, annotfiles_val, 
                            select_genes=select_genes, img_transforms=preprocess)
# Out:
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_62 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 2_64 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 55_55 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_26 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 57_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 33_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 21_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_38 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 27_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 9_73 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 99_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 75_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 13_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 45_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 109_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 115_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 69_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 105_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 63_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 4_68 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_60 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 97_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_58 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_36 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 89_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 10_76 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_56 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_28 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 113_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_32 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 55_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 91_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 53_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 25_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 85_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 83_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_52 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 107_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 8_72 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_46 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 17_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_24 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 29_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 2_66 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 121_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_12 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 65_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 37_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 11_73 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 87_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 59_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_44 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 123_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 72_30 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 67_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 71_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 3_67 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 93_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 5_69 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 39_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_18 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 127_57 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 79_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 43_77 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 0_64 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/ 101_17 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151510_full_image/
no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 114_40 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 117_51 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 118_50 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 113_19 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 117_47 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 42_72 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 106_64 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 113_35 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 74_68 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 41_71 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 115_39 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 106_8 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 113_21 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 103_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 116_40 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 101_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 114_62 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 12_8 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 113_59 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 102_2 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 113_63 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 112_30 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 114_34 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 120_14 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 105_7 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 107_11 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 120_52 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 103_65 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 111_25 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 116_38 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 114_32 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 41_69 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 116_46 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 101_1 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151673_full_image/ 116_36 no image data
# ...
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 106_8 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 113_21 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 44_2 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 121_39 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 125_57 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 103_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 120_40 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 106_14 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 15_69 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 109_17 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 101_7 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 121_49 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 46_68 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 123_57 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 69_67 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_40 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 101_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_62 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 123_55 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_35 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 71_67 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 48_70 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 120_34 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 113_63 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 112_30 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 123_51 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_34 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 105_7 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 122_44 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 123_49 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 51_1 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_26 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 112_12 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_43 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 107_11 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 54_0 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 120_52 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 97_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 104_8 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 121_53 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 110_28 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 111_25 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_38 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_32 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 124_52 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 47_71 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 41_5 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 98_4 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_36 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 39_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 75_67 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 115_23 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_59 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_41 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_53 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 118_40 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 53_1 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_25 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 122_54 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 124_48 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 113_61 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 24_68 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_47 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 41_3 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 120_50 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 107_17 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 112_26 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 35_5 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 32_6 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_35 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 118_54 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_24 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 110_22 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_39 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 124_56 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 115_29 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_28 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 121_51 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 110_14 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 113_31 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 108_14 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 120_46 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 106_12 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 69_69 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_57 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 111_63 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 109_9 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 46_2 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 109_15 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 106_16 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_53 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 118_34 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 52_0 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_60 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_34 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 120_58 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 39_5 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_30 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 111_13 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 96_4 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_33 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 94_0 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 17_9 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 14_10 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 99_5 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 100_64 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_54 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_26 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 112_24 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 112_62 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 110_10 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 109_21 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 118_44 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 116_58 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 122_46 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 114_22 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 37_5 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 100_2 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 115_19 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 112_22 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 121_55 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 110_12 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 115_41 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_41 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 99_7 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_61 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 121_47 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 118_38 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 119_39 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 115_27 no image data
# /Users/adaly/Documents/Splotch_projects/Maynard_DLPFC/data/maynard_patchdata_oddr/151676_full_image/ 117_33 no image data

# %%
# Construct a network that takes an image patch and outputs an expression vector

x_count, x_img, y = mmp_train[0]
n_genes = x_count.shape[0]

# load a pre-trained DenseNet121
densenet = models.densenet121(True)

# Change final layer to predict gene dimension; Sigmoid activation ensures values fall in normalized 0,1 range.
densenet.classifier = nn.Sequential(
    nn.Linear(1024, n_genes),
    nn.Sigmoid()
)

pred = densenet(torch.unsqueeze(x_img,0))
print(pred)
# Out:
# tensor([[0.2759, 0.5301, 0.4844, 0.4730, 0.5630, 0.5016, 0.5452, 0.4289, 0.3434,
#          0.5279, 0.6469, 0.4337, 0.6727, 0.5018]], grad_fn=<SigmoidBackward>)

# %%
def train_selfsupervised(model, dataloaders, criterion, optimizer, num_epochs, 
                         outfile=None, display=None):
    since = time.time()
    train_loss_hist, val_loss_hist = [],[]
    best_loss = np.inf
    
    # GPU support
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    best_model_wts = copy.deepcopy(model.state_dict())

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1), flush=True)
        print('-' * 10, flush=True)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            if display:
                iterator = progressbar.progressbar(dataloaders[phase])
            else:
                iterator = dataloaders[phase]
            
            running_loss = 0

            for x_count, x_img, y in iterator:
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase=='train'):
                    counts_pred = model(x_img)
                    loss = criterion(x_count, counts_pred)
                                        
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                running_loss += loss.item()
            epoch_loss = running_loss / len(dataloaders[phase])
            
            if phase == 'val':
                if epoch_loss < best_loss:
                    best_loss = epoch_loss
                    best_model_wts = copy.deepcopy(model.state_dict())
                    
                    if outfile is not None:
                        torch.save(model.state_dict(), outfile)
                val_loss_hist.append(val_loss)
            else:
                train_loss_hist.append(train_loss)
    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60), flush=True)
    print('Best val loss: {:4f}'.format(best_loss), flush=True)

mmp_dataloaders = {
    'train': DataLoader(mmp_train, batch_size=32, shuffle=True),
    'val': DataLoader(mmp_val, batch_size=32, shuffle=False)
}

criterion = nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(densenet.parameters(), lr=1e-4)
    
train_selfsupervised(densenet, mmp_dataloaders, criterion, optimizer, 10)
# Out:
# Epoch 0/9
# ----------
# tensor(0.1294, grad_fn=<MseLossBackward>)
# tensor(0.1283, grad_fn=<MseLossBackward>)
# tensor(0.1258, grad_fn=<MseLossBackward>)
# tensor(0.1157, grad_fn=<MseLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-b41d029ac046> in <module>
#      70 optimizer = torch.optim.Adam(densenet.parameters(), lr=1e-4)
#      71
# ---> 72 train_selfsupervised(densenet, mmp_dataloaders, criterion, optimizer, 10)
#
# <ipython-input-42-b41d029ac046> in train_selfsupervised(model, dataloaders, criterion, optimizer, num_epochs, outfile, display)
#      35
#      36                 with torch.set_grad_enabled(phase=='train'):
# ---> 37                     counts_pred = model(x_img)
#      38                     loss = criterion(x_count, counts_pred)
#      39
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/densenet.py in forward(self, x)
#     153
#     154     def forward(self, x):
# --> 155         features = self.features(x)
#     156         out = F.relu(features, inplace=True)
#     157         out = F.adaptive_avg_pool2d(out, (1, 1))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/densenet.py in forward(self, init_features)
#      72         features = [init_features]
#      73         for name, layer in self.named_children():
# ---> 74             new_features = layer(*features)
#      75             features.append(new_features)
#      76         return torch.cat(features, 1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/densenet.py in forward(self, *prev_features)
#      49         else:
#      50             bottleneck_output = bn_function(*prev_features)
# ---> 51         new_features = self.conv2(self.relu2(self.norm2(bottleneck_output)))
#      52         if self.drop_rate > 0:
#      53             new_features = F.dropout(new_features, p=self.drop_rate,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     438                             _pair(0), self.dilation, self.groups)
#     439         return F.conv2d(input, weight, bias, self.stride,
# --> 440                         self.padding, self.dilation, self.groups)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:
