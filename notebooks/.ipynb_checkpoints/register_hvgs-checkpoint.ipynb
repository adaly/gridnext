# %%
import sys, os, glob
import pandas as pd
import numpy as np
from pathlib import Path

import matplotlib
matplotlib.use('TkAgg')
from matplotlib import pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.utils.data import DataLoader

sys.path.append('../src/')
from training import train_spotwise, train_gridwise
from count_datasets import load_count_dataset, load_count_grid_dataset, read_annotated_starray
from count_datasets import CountDataset, CountGridDataset

from scanpy.pp import highly_variable_genes
from anndata import AnnData

# %%
# Find highly variable genes according to the method of Seurat_V3, which operates on (raw) count data.
# - z-score normalization performed per feature (gene)
# - calculate variance of each gene after normalization, return genes w/highest values

data_dir = os.path.expanduser('~/Documents/Splotch_projects/Maynard_DLPFC/data/')

X = []
files, coords = [],[]

for cfile in glob.glob(os.path.join(data_dir, 'Countfiles_Visium', '*.unified.tsv')):
    count_dat = pd.read_csv(cfile, sep='\t', header=0, index_col=0)
    X.append(count_dat.values.T)
    
    coords += list(count_dat.columns)
    files += [Path(cfile).name] * len(count_dat.columns)
X = np.vstack(X)

var = pd.DataFrame(index=count_dat.index)
obs = pd.DataFrame({'st_file': files, 'st_coord': coords})

adata = AnnData(X, obs=obs, var=var)

highly_variable_genes(adata, flavor='seurat_v3', n_top_genes=2150)

# %%
# See which of Joana's marker genes are included in the set of automatically-derived HVGs
jp_markers = {
    'MBP': 'ENSG00000197971',    # WM
    'SNAP25': 'ENSG00000132639', # GM (Layers 1-6)
    'PCP4': 'ENSG00000183036',   # Layer 5
    'RORB': 'ENSG00000198963',   # Layer 4
    'SYNPR': 'ENSG00000163630',  # Layer 6
    'MFGE8': 'ENSG00000140545',
    'CBLN2': 'ENSG00000141668',
    'RPRM': 'ENSG00000177519',
    'NR4A2': 'ENSG00000153234',
    'CXCL14': 'ENSG00000145824',
    'C1QL2': 'ENSG00000144119',
    'CUX2': 'ENSG00000111249',
    'CARTPT': 'ENSG00000164326',
    'CCK': 'ENSG00000187094'
}

for key, val in jp_markers.items():
    if not adata.var.loc[val, 'highly_variable']:
        print(key, "is not a HVG")

# %%
hvgs = adata.var.index[adata.var['highly_variable']]

train_tissues = ['151507', '151508', '151509', '151510', '151669', '151670', '151671', '151672', '151673', '151674']
val_tissues = ['151675', '151676']

countfiles_train = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs.txt.unified.tsv') % s for s in train_tissues]
annotfiles_train = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in train_tissues]

countfiles_val = [os.path.join(data_dir, 'Countfiles_Visium_norm/%s_stdata_aligned_counts_IDs.txt.unified.tsv') % s for s in val_tissues]
annotfiles_val = [os.path.join(data_dir, 'Covariates_Visium/%s.tsv') % s for s in val_tissues]

# Load full datasets into memory for quick training
train_spot_hvg = load_count_dataset(countfiles_train, annotfiles_train, select_genes=hvgs)
val_spot_hvg = load_count_dataset(countfiles_val, annotfiles_val, select_genes=hvgs)

dataloader_spot_hvg = {
    'train': DataLoader(train_spot_hvg, batch_size=32, shuffle=True),
    'val': DataLoader(val_spot_hvg, batch_size=32)
}

# %%
# Fit a basic fully-connected network to the top 2150 HVGs
df = pd.read_csv(annotfiles_train[0], header=0, index_col=0, sep='\t')
annot_names = list(df.index.values)

spot_clf_hvg = nn.Sequential(
    nn.Linear(len(hvgs), 500),
    nn.Linear(500, 100),
    nn.BatchNorm1d(100),
    nn.ReLU(),
    
    nn.Linear(100, 100),
    nn.Linear(100, 50),
    nn.BatchNorm1d(50),
    nn.ReLU(),
    
    nn.Linear(50, len(annot_names))
)

loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(spot_clf_hvg.parameters(), lr=1e-4)

spot_clf_hvg, val_hist, train_hist = train_spotwise(spot_clf_hvg, dataloader_spot_hvg, loss, optimizer, 100, 
                                                    display=False, outfile='../models/spot_classifier_hvg.pth')

fig = plt.figure()
plt.plot(train_hist, label='train')
plt.plot(val_hist, label='val')
plt.legend()
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.9147 Acc: 0.7091
# val Loss: 0.8310 Acc: 0.6872
#
# Epoch 1/99
# ----------
# train Loss: 0.5920 Acc: 0.7873
# val Loss: 0.7959 Acc: 0.7049
#
# Epoch 2/99
# ----------
# train Loss: 0.4948 Acc: 0.8180
# val Loss: 0.8197 Acc: 0.7020
#
# Epoch 3/99
# ----------
# train Loss: 0.4033 Acc: 0.8537
# val Loss: 0.7888 Acc: 0.7133
#
# Epoch 4/99
# ----------
# train Loss: 0.3097 Acc: 0.8941
# val Loss: 0.9333 Acc: 0.6939
#
# Epoch 5/99
# ----------
# train Loss: 0.2294 Acc: 0.9270
# val Loss: 1.0889 Acc: 0.6781
#
# Epoch 6/99
# ----------
# train Loss: 0.1651 Acc: 0.9511
# val Loss: 1.0840 Acc: 0.6801
#
# Epoch 7/99
# ----------
# train Loss: 0.1281 Acc: 0.9624
# val Loss: 1.1959 Acc: 0.6731
#
# Epoch 8/99
# ----------
# train Loss: 0.1051 Acc: 0.9701
# val Loss: 1.2681 Acc: 0.6656
#
# Epoch 9/99
# ----------
# train Loss: 0.0875 Acc: 0.9750
# val Loss: 1.3885 Acc: 0.6614
#
# Epoch 10/99
# ----------
# train Loss: 0.0766 Acc: 0.9784
# val Loss: 1.4596 Acc: 0.6604
#
# Epoch 11/99
# ----------
# train Loss: 0.0678 Acc: 0.9794
# val Loss: 1.4239 Acc: 0.6744
#
# Epoch 12/99
# ----------
# train Loss: 0.0636 Acc: 0.9806
# val Loss: 1.4528 Acc: 0.6707
#
# Epoch 13/99
# ----------
# train Loss: 0.0575 Acc: 0.9821
# val Loss: 1.7171 Acc: 0.6513
#
# Epoch 14/99
# ----------
# train Loss: 0.0549 Acc: 0.9828
# val Loss: 1.5626 Acc: 0.6634
#
# Epoch 15/99
# ----------
# train Loss: 0.0529 Acc: 0.9833
# val Loss: 1.6820 Acc: 0.6581
#
# Epoch 16/99
# ----------
# train Loss: 0.0464 Acc: 0.9855
# val Loss: 1.6511 Acc: 0.6716
#
# Epoch 17/99
# ----------
# train Loss: 0.0485 Acc: 0.9843
# val Loss: 1.6020 Acc: 0.6726
#
# Epoch 18/99
# ----------
# train Loss: 0.0442 Acc: 0.9859
# val Loss: 1.8350 Acc: 0.6557
#
# Epoch 19/99
# ----------
# train Loss: 0.0450 Acc: 0.9849
# val Loss: 1.6629 Acc: 0.6686
#
# Epoch 20/99
# ----------
# train Loss: 0.0407 Acc: 0.9866
# val Loss: 2.0256 Acc: 0.6511
#
# Epoch 21/99
# ----------
# train Loss: 0.0381 Acc: 0.9870
# val Loss: 1.6630 Acc: 0.6709
#
# Epoch 22/99
# ----------
# train Loss: 0.0413 Acc: 0.9863
# val Loss: 1.7899 Acc: 0.6661
#
# Epoch 23/99
# ----------
# train Loss: 0.0383 Acc: 0.9879
# val Loss: 1.9434 Acc: 0.6533
#
# Epoch 24/99
# ----------
# train Loss: 0.0365 Acc: 0.9878
# val Loss: 1.7885 Acc: 0.6631
#
# Epoch 25/99
# ----------
# train Loss: 0.0331 Acc: 0.9897
# val Loss: 1.9414 Acc: 0.6596
#
# Epoch 26/99
# ----------
# train Loss: 0.0318 Acc: 0.9894
# val Loss: 1.9961 Acc: 0.6646
#
# Epoch 27/99
# ----------
# train Loss: 0.0311 Acc: 0.9904
# val Loss: 2.0933 Acc: 0.6507
#
# Epoch 28/99
# ----------
# train Loss: 0.0338 Acc: 0.9883
# val Loss: 2.0056 Acc: 0.6581
#
# Epoch 29/99
# ----------
# train Loss: 0.0296 Acc: 0.9903
# val Loss: 2.0866 Acc: 0.6554
#
# Epoch 30/99
# ----------
# train Loss: 0.0302 Acc: 0.9900
# val Loss: 2.1518 Acc: 0.6644
#
# Epoch 31/99
# ----------
# train Loss: 0.0297 Acc: 0.9905
# val Loss: 1.8598 Acc: 0.6686
#
# Epoch 32/99
# ----------
# train Loss: 0.0278 Acc: 0.9909
# val Loss: 1.9323 Acc: 0.6631
#
# Epoch 33/99
# ----------
# train Loss: 0.0258 Acc: 0.9918
# val Loss: 2.1551 Acc: 0.6619
#
# Epoch 34/99
# ----------
# train Loss: 0.0298 Acc: 0.9902
# val Loss: 2.0326 Acc: 0.6590
#
# Epoch 35/99
# ----------
# train Loss: 0.0275 Acc: 0.9905
# val Loss: 1.9386 Acc: 0.6631
#
# Epoch 36/99
# ----------
# train Loss: 0.0285 Acc: 0.9910
# val Loss: 2.0813 Acc: 0.6557
#
# Epoch 37/99
# ----------
# train Loss: 0.0260 Acc: 0.9912
# val Loss: 2.1199 Acc: 0.6573
#
# Epoch 38/99
# ----------
# train Loss: 0.0246 Acc: 0.9917
# val Loss: 1.9722 Acc: 0.6594
#
# Epoch 39/99
# ----------
# train Loss: 0.0198 Acc: 0.9940
# val Loss: 2.0224 Acc: 0.6701
#
# Epoch 40/99
# ----------
# train Loss: 0.0243 Acc: 0.9919
# val Loss: 2.0571 Acc: 0.6601
#
# Epoch 41/99
# ----------
# train Loss: 0.0260 Acc: 0.9917
# val Loss: 2.0467 Acc: 0.6630
#
# Epoch 42/99
# ----------
# train Loss: 0.0247 Acc: 0.9918
# val Loss: 2.0613 Acc: 0.6534
#
# Epoch 43/99
# ----------
# train Loss: 0.0225 Acc: 0.9926
# val Loss: 2.2748 Acc: 0.6537
#
# Epoch 44/99
# ----------
# train Loss: 0.0207 Acc: 0.9931
# val Loss: 2.0656 Acc: 0.6670
#
# Epoch 45/99
# ----------
# train Loss: 0.0216 Acc: 0.9930
# val Loss: 2.0159 Acc: 0.6619
#
# Epoch 46/99
# ----------
# train Loss: 0.0249 Acc: 0.9915
# val Loss: 2.3257 Acc: 0.6454
#
# Epoch 47/99
# ----------
# train Loss: 0.0210 Acc: 0.9933
# val Loss: 2.1472 Acc: 0.6640
#
# Epoch 48/99
# ----------
# train Loss: 0.0198 Acc: 0.9934
# val Loss: 2.1034 Acc: 0.6603
#
# Epoch 49/99
# ----------
# train Loss: 0.0202 Acc: 0.9933
# val Loss: 2.3325 Acc: 0.6561
#
# Epoch 50/99
# ----------
# train Loss: 0.0196 Acc: 0.9934
# val Loss: 2.1940 Acc: 0.6656
#
# Epoch 51/99
# ----------
# train Loss: 0.0191 Acc: 0.9937
# val Loss: 2.2572 Acc: 0.6596
#
# Epoch 52/99
# ----------
# train Loss: 0.0199 Acc: 0.9939
# val Loss: 2.3088 Acc: 0.6536
#
# Epoch 53/99
# ----------
# train Loss: 0.0196 Acc: 0.9931
# val Loss: 2.4918 Acc: 0.6471
#
# Epoch 54/99
# ----------
# train Loss: 0.0175 Acc: 0.9942
# val Loss: 2.1843 Acc: 0.6681
#
# Epoch 55/99
# ----------
# train Loss: 0.0198 Acc: 0.9933
# val Loss: 2.1379 Acc: 0.6627
#
# Epoch 56/99
# ----------
# train Loss: 0.0193 Acc: 0.9932
# val Loss: 2.3882 Acc: 0.6521
#
# Epoch 57/99
# ----------
# train Loss: 0.0194 Acc: 0.9935
# val Loss: 2.1741 Acc: 0.6693
#
# Epoch 58/99
# ----------
# train Loss: 0.0190 Acc: 0.9940
# val Loss: 2.3762 Acc: 0.6543
#
# Epoch 59/99
# ----------
# train Loss: 0.0175 Acc: 0.9945
# val Loss: 2.4895 Acc: 0.6476
#
# Epoch 60/99
# ----------
# train Loss: 0.0184 Acc: 0.9938
# val Loss: 2.1977 Acc: 0.6613
#
# Epoch 61/99
# ----------
# train Loss: 0.0175 Acc: 0.9940
# val Loss: 2.4530 Acc: 0.6460
#
# Epoch 62/99
# ----------
# train Loss: 0.0187 Acc: 0.9938
# val Loss: 2.2498 Acc: 0.6586
#
# Epoch 63/99
# ----------
# train Loss: 0.0171 Acc: 0.9943
# val Loss: 2.4077 Acc: 0.6579
#
# Epoch 64/99
# ----------
# train Loss: 0.0177 Acc: 0.9941
# val Loss: 2.4866 Acc: 0.6607
#
# Epoch 65/99
# ----------
# train Loss: 0.0151 Acc: 0.9954
# val Loss: 2.2987 Acc: 0.6624
#
# Epoch 66/99
# ----------
# train Loss: 0.0163 Acc: 0.9945
# val Loss: 2.4013 Acc: 0.6579
#
# Epoch 67/99
# ----------
# train Loss: 0.0131 Acc: 0.9959
# val Loss: 2.4738 Acc: 0.6541
#
# Epoch 68/99
# ----------
# train Loss: 0.0163 Acc: 0.9947
# val Loss: 2.7364 Acc: 0.6466
#
# Epoch 69/99
# ----------
# train Loss: 0.0186 Acc: 0.9937
# val Loss: 2.2695 Acc: 0.6627
#
# Epoch 70/99
# ----------
# train Loss: 0.0155 Acc: 0.9949
# val Loss: 2.2748 Acc: 0.6621
#
# Epoch 71/99
# ----------
# train Loss: 0.0142 Acc: 0.9955
# val Loss: 2.4462 Acc: 0.6599
#
# Epoch 72/99
# ----------
# train Loss: 0.0160 Acc: 0.9947
# val Loss: 2.4332 Acc: 0.6554
#
# Epoch 73/99
# ----------
# train Loss: 0.0140 Acc: 0.9953
# val Loss: 2.3075 Acc: 0.6666
#
# Epoch 74/99
# ----------
# train Loss: 0.0147 Acc: 0.9953
# val Loss: 2.2765 Acc: 0.6574
#
# Epoch 75/99
# ----------
# train Loss: 0.0148 Acc: 0.9949
# val Loss: 2.2571 Acc: 0.6660
#
# Epoch 76/99
# ----------
# train Loss: 0.0144 Acc: 0.9949
# val Loss: 2.4320 Acc: 0.6626
#
# Epoch 77/99
# ----------
# train Loss: 0.0136 Acc: 0.9954
# val Loss: 2.4161 Acc: 0.6624
#
# Epoch 78/99
# ----------
# train Loss: 0.0144 Acc: 0.9952
# val Loss: 2.4135 Acc: 0.6557
#
# Epoch 79/99
# ----------
# train Loss: 0.0130 Acc: 0.9955
# val Loss: 2.4882 Acc: 0.6576
#
# Epoch 80/99
# ----------
# train Loss: 0.0159 Acc: 0.9945
# val Loss: 2.4241 Acc: 0.6633
#
# Epoch 81/99
# ----------
# train Loss: 0.0132 Acc: 0.9958
# val Loss: 2.3875 Acc: 0.6647
#
# Epoch 82/99
# ----------
# train Loss: 0.0148 Acc: 0.9949
# val Loss: 2.3869 Acc: 0.6643
#
# Epoch 83/99
# ----------
# train Loss: 0.0138 Acc: 0.9952
# val Loss: 2.6335 Acc: 0.6540
#
# Epoch 84/99
# ----------
# train Loss: 0.0137 Acc: 0.9950
# val Loss: 2.5121 Acc: 0.6626
#
# Epoch 85/99
# ----------
# train Loss: 0.0138 Acc: 0.9954
# val Loss: 2.4489 Acc: 0.6597
#
# Epoch 86/99
# ----------
# train Loss: 0.0138 Acc: 0.9952
# val Loss: 2.5831 Acc: 0.6544
#
# Epoch 87/99
# ----------
# train Loss: 0.0107 Acc: 0.9967
# val Loss: 2.4811 Acc: 0.6581
#
# Epoch 88/99
# ----------
# train Loss: 0.0106 Acc: 0.9965
# val Loss: 2.5067 Acc: 0.6636
#
# Epoch 89/99
# ----------
# train Loss: 0.0146 Acc: 0.9954
# val Loss: 2.5029 Acc: 0.6577
#
# Epoch 90/99
# ----------
# train Loss: 0.0131 Acc: 0.9956
# val Loss: 2.4964 Acc: 0.6661
#
# Epoch 91/99
# ----------
# train Loss: 0.0131 Acc: 0.9956
# val Loss: 2.4577 Acc: 0.6500
#
# Epoch 92/99
# ----------
# train Loss: 0.0127 Acc: 0.9955
# val Loss: 2.4623 Acc: 0.6641
#
# Epoch 93/99
# ----------
# train Loss: 0.0120 Acc: 0.9957
# val Loss: 2.7033 Acc: 0.6490
#
# Epoch 94/99
# ----------
# train Loss: 0.0125 Acc: 0.9954
# val Loss: 2.6163 Acc: 0.6579
#
# Epoch 95/99
# ----------
# train Loss: 0.0120 Acc: 0.9960
# val Loss: 2.4956 Acc: 0.6556
#
# Epoch 96/99
# ----------
# train Loss: 0.0128 Acc: 0.9956
# val Loss: 2.5824 Acc: 0.6630
#
# Epoch 97/99
# ----------
# train Loss: 0.0111 Acc: 0.9963
# val Loss: 2.4964 Acc: 0.6666
# Epoch 98/99
# ----------
# train Loss: 0.0123 Acc: 0.9956
# val Loss: 2.3227 Acc: 0.6677
#
# Epoch 99/99
# ----------
# train Loss: 0.0120 Acc: 0.9962
# val Loss: 2.5204 Acc: 0.6589
#
# Training complete in 14m 3s
# Best val Acc: 0.713306
